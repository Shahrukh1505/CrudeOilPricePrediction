# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://pkgstore.datahub.io/core/oil-prices/wti-year_csv/data/e712eaaeb04770dec3df8a7f442eac68/wti-year_csv.csv")

# %%
df
# Out:
#           Date  WTI Spot Price
# 0   1986-11-15           15.05
# 1   1987-11-15           19.20
# 2   1988-11-15           15.97
# 3   1989-11-15           19.64
# 4   1990-11-15           24.53
# 5   1991-11-15           21.54
# 6   1992-11-15           20.58
# 7   1993-11-15           18.43
# 8   1994-11-15           17.20
# 9   1995-11-15           18.43
# 10  1996-11-15           22.12
# 11  1997-11-15           20.61
# 12  1998-11-15           14.42
# 13  1999-11-15           19.34
# 14  2000-11-15           30.38
# 15  2001-11-15           25.98
# 16  2002-11-15           26.18
# 17  2003-11-15           31.08
# 18  2004-11-15           41.51
# 19  2005-11-15           56.64
# 20  2006-11-15           66.05
# 21  2007-11-15           72.34
# 22  2008-11-15           99.67
# 23  2009-11-15           61.95
# 24  2010-11-15           79.48
# 25  2011-11-15           94.88
# 26  2012-11-15           94.05
# 27  2013-11-15           97.98
# 28  2014-11-15           93.17
# ...

# %%
dataset = pd.DataFrame(df)

# %%
dataset
# Out:
#           Date  WTI Spot Price
# 0   1986-11-15           15.05
# 1   1987-11-15           19.20
# 2   1988-11-15           15.97
# 3   1989-11-15           19.64
# 4   1990-11-15           24.53
# 5   1991-11-15           21.54
# 6   1992-11-15           20.58
# 7   1993-11-15           18.43
# 8   1994-11-15           17.20
# 9   1995-11-15           18.43
# 10  1996-11-15           22.12
# 11  1997-11-15           20.61
# 12  1998-11-15           14.42
# 13  1999-11-15           19.34
# 14  2000-11-15           30.38
# 15  2001-11-15           25.98
# 16  2002-11-15           26.18
# 17  2003-11-15           31.08
# 18  2004-11-15           41.51
# 19  2005-11-15           56.64
# 20  2006-11-15           66.05
# 21  2007-11-15           72.34
# 22  2008-11-15           99.67
# 23  2009-11-15           61.95
# 24  2010-11-15           79.48
# 25  2011-11-15           94.88
# 26  2012-11-15           94.05
# 27  2013-11-15           97.98
# 28  2014-11-15           93.17
# ...

# %%
dataset.head()
# Out:
#          Date  WTI Spot Price
# 0  1986-11-15           15.05
# 1  1987-11-15           19.20
# 2  1988-11-15           15.97
# 3  1989-11-15           19.64
# 4  1990-11-15           24.53

# %%
x = ["python","c","c++","java"]
y = [85, 70, 60, 82]
z = [33, 44, 56, 80]
plt.xlabel("languages", fontsize=20)
plt.ylabel("popularity", fontsize=20)
plt.title("Data", fontsize = 25)
c = ["y","b","m","g"]
plt.bar(x,y, width=0.6, color="r", align="center",edgecolor="black",linewidth=2, label="growth")
plt.bar(x,z, width=0.6, color="y", align="center",edgecolor="black",linewidth=2, label="growth2")
plt.legend()

plt.show()

# %%
print(df.columns)
# Out:
# Index(['Date', 'WTI Spot Price'], dtype='object')

# %%
x = list(df['Date'])


y = list(df['WTI Spot Price'])

p=[]
for i in x:
    p.append(i[2] + i[3] + "")
    
plt.bar(p, y, width=0.3)
plt.show()
print(p)
# Out:
# ['86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99', '00', '01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12', '13', '14', '15']

# %%
# Out:
#   Cell In[26], line 1
#     print(list(df['Date'].head())
#                                  ^
# SyntaxError: unexpected EOF while parsing
