# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Shahrukh Ansari\Desktop\majorProject\files\data.csv")

# %%
df
# Out:
#               Date  Price
# 0     Dec 09, 2005  59.39
# 1     Dec 08, 2005  60.66
# 2     Dec 07, 2005  59.21
# 3     Dec 06, 2005  59.94
# 4     Dec 05, 2005  59.91
# ...            ...    ...
# 8632  Jan 31, 5652  58.06
# 8633  Jan 31, 5653  59.99
# 8634  Jan 31, 5654  60.85
# 8635  Jan 31, 5655  61.37
# 8636  Jan 31, 5656  61.30
#
# [8637 rows x 2 columns]

# %%
df.head()
# Out:
#            Date  Price
# 0  Dec 09, 2005  59.39
# 1  Dec 08, 2005  60.66
# 2  Dec 07, 2005  59.21
# 3  Dec 06, 2005  59.94
# 4  Dec 05, 2005  59.91

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8637 entries, 0 to 8636
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    8637 non-null   object
#  1   Price   8637 non-null   float64
#  2   year    8637 non-null   int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 202.6+ KB

# %%
df.describe()
# Out:
#              Price         year
# count  8637.000000  8637.000000
# mean     44.446854  2771.342827
# std      29.168667  1136.641008
# min      10.420000  1986.000000
# 25%      19.760000  1994.000000
# 50%      31.730000  2003.000000
# 75%      63.510000  3497.000000
# max     145.290000  5656.000000

# %%
df.tail()
# Out:
#               Date  Price  year
# 8632  Jan 31, 5652  58.06  5652
# 8633  Jan 31, 5653  59.99  5653
# 8634  Jan 31, 5654  60.85  5654
# 8635  Jan 31, 5655  61.37  5655
# 8636  Jan 31, 5656  61.30  5656

# %%
l = []
for i in df['Date']:
    l.append(int(i[8]+i[9]+i[10]+i[11]))
df['year'] = l;

# %%
pd.to_datetime(df.Date, errors = 'ignore')
# Out:
# 0       Dec 09, 2005
# 1       Dec 08, 2005
# 2       Dec 07, 2005
# 3       Dec 06, 2005
# 4       Dec 05, 2005
#             ...
# 8632    Jan 31, 5652
# 8633    Jan 31, 5653
# 8634    Jan 31, 5654
# 8635    Jan 31, 5655
# 8636    Jan 31, 5656
# Name: Date, Length: 8637, dtype: object

# %%
df.Date = pd.to_datetime(df.Date)
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.Date = pd.to_datetime(df.Date)
#
# File c:\users\shahrukh ansari\appdata\local\programs\python\python39\lib\site-packages\pandas\core\tools\datetimes.py:1050, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1048         result = arg.map(cache_array)
#    1049     else:
# -> 1050         values = convert_listlike(arg._values, format)
#    1051         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1052 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\users\shahrukh ansari\appdata\local\programs\python\python39\lib\site-packages\pandas\core\tools\datetimes.py:453, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     451 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     452 if format is not None and format != "mixed":
# --> 453     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     455 result, tz_parsed = objects_to_datetime64ns(
#     456     arg,
#     457     dayfirst=dayfirst,
#    (...)
#     461     allow_object=True,
#     462 )
#     464 if tz_parsed is not None:
#     465     # We can take a shortcut since the datetime64 numpy array
#     466     # is in UTC
#
# File c:\users\shahrukh ansari\appdata\local\programs\python\python39\lib\site-packages\pandas\core\tools\datetimes.py:484, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     473 def _array_strptime_with_fallback(
#     474     arg,
#     475     name,
#    (...)
#     479     errors: str,
#     480 ) -> Index:
#     481     """
#     482     Call array_strptime, with fallback behavior depending on 'errors'.
#     483     """
# --> 484     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     485     if any(tz is not None for tz in timezones):
#     486         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# File c:\users\shahrukh ansari\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\tslibs\strptime.pyx:530, in pandas._libs.tslibs.strptime.array_strptime()
#
# File c:\users\shahrukh ansari\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\tslibs\strptime.pyx:512, in pandas._libs.tslibs.strptime.array_strptime()
#
# File c:\users\shahrukh ansari\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\tslibs\np_datetime.pyx:218, in pandas._libs.tslibs.np_datetime.check_dts_bounds()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 2263-01-31 00:00:00, at position 5243. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
df
# Out:
#               Date  Price  year
# 0     Dec 09, 2005  59.39  2005
# 1     Dec 08, 2005  60.66  2005
# 2     Dec 07, 2005  59.21  2005
# 3     Dec 06, 2005  59.94  2005
# 4     Dec 05, 2005  59.91  2005
# ...            ...    ...   ...
# 8632  Jan 31, 5652  58.06  5652
# 8633  Jan 31, 5653  59.99  5653
# 8634  Jan 31, 5654  60.85  5654
# 8635  Jan 31, 5655  61.37  5655
# 8636  Jan 31, 5656  61.30  5656
#
# [8637 rows x 3 columns]
