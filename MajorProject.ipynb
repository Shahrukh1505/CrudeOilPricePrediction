# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("https://pkgstore.datahub.io/core/oil-prices/wti-day_csv/data/3ee9614b39c99ec7ec5e35c3df3deff3/wti-day_csv.csv")

# %%
df
# Out:
#             Date  WTI Spot Price
# 0     1986-01-02           25.56
# 1     1986-01-03           26.00
# 2     1986-01-06           26.53
# 3     1986-01-07           25.85
# 4     1986-01-08           25.87
# ...          ...             ...
# 7588  2016-02-02           29.90
# 7589  2016-02-03           32.29
# 7590  2016-02-04           31.63
# 7591  2016-02-05           30.86
# 7592  2016-02-08           29.71
#
# [7593 rows x 2 columns]

# %%
df.head()
# Out:
#          Date  WTI Spot Price
# 0  1986-01-02           25.56
# 1  1986-01-03           26.00
# 2  1986-01-06           26.53
# 3  1986-01-07           25.85
# 4  1986-01-08           25.87

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7593 entries, 0 to 7592
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            7593 non-null   object
#  1   WTI Spot Price  7593 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 118.8+ KB

# %%
df.describe()
# Out:
#        WTI Spot Price
# count     7593.000000
# mean        42.813836
# std         30.601262
# min         10.250000
# 25%         19.270000
# 50%         27.240000
# 75%         65.110000
# max        145.310000

# %%
plt.figure(figsize=(15,10))
df['WTI Spot Price'].plot(kind='bar')
plt.title('Variation of oil price over years')
plt.ylabel('Price')
plt.xticks(color = 'w',rotation=90)
# Out:
# (array([   0,    1,    2, ..., 7590, 7591, 7592]),
#  [Text(0, 0, '0'),
#   Text(1, 0, '1'),
#   Text(2, 0, '2'),
#   Text(3, 0, '3'),
#   Text(4, 0, '4'),
#   Text(5, 0, '5'),
#   Text(6, 0, '6'),
#   Text(7, 0, '7'),
#   Text(8, 0, '8'),
#   Text(9, 0, '9'),
#   Text(10, 0, '10'),
#   Text(11, 0, '11'),
#   Text(12, 0, '12'),
#   Text(13, 0, '13'),
#   Text(14, 0, '14'),
#   Text(15, 0, '15'),
#   Text(16, 0, '16'),
#   Text(17, 0, '17'),
#   Text(18, 0, '18'),
#   Text(19, 0, '19'),
#   Text(20, 0, '20'),
#   Text(21, 0, '21'),
#   Text(22, 0, '22'),
#   Text(23, 0, '23'),
#   Text(24, 0, '24'),
#   Text(25, 0, '25'),
#   Text(26, 0, '26'),
#   Text(27, 0, '27'),
#   Text(28, 0, '28'),
#   Text(29, 0, '29'),
#   Text(30, 0, '30'),
#   Text(31, 0, '31'),
#   Text(32, 0, '32'),
#   Text(33, 0, '33'),
#   Text(34, 0, '34'),
#   Text(35, 0, '35'),
#   Text(36, 0, '36'),
#   Text(37, 0, '37'),
#   Text(38, 0, '38'),
#   Text(39, 0, '39'),
#   Text(40, 0, '40'),
#   Text(41, 0, '41'),
# ...

# %%
plt.figure(figsize=(15,10))
df['WTI Spot Price'].plot(kind='line')
plt.title('Variation of oil price over years')
plt.ylabel('Price')
plt.xticks(color = 'w')
# Out:
# (array([-1000.,     0.,  1000.,  2000.,  3000.,  4000.,  5000.,  6000.,
#          7000.,  8000.]),
#  [Text(-1000.0, 0, '−1000'),
#   Text(0.0, 0, '0'),
#   Text(1000.0, 0, '1000'),
#   Text(2000.0, 0, '2000'),
#   Text(3000.0, 0, '3000'),
#   Text(4000.0, 0, '4000'),
#   Text(5000.0, 0, '5000'),
#   Text(6000.0, 0, '6000'),
#   Text(7000.0, 0, '7000'),
#   Text(8000.0, 0, '8000')])

# %%
l = []
for i in df['Date']:
    l.append(int(i[0]+i[1]+i[2]+i[3]))
df['year'] = l;

# %%
df.head()
# Out:
#          Date  WTI Spot Price  year
# 0  1986-01-02           25.56  1986
# 1  1986-01-03           26.00  1986
# 2  1986-01-06           26.53  1986
# 3  1986-01-07           25.85  1986
# 4  1986-01-08           25.87  1986

# %%
x=df['year']
y=df['WTI Spot Price']
plt.bar(x,y)
plt.title('Variation of Price over years')
plt.xlabel('Year')
plt.ylabel('Price in $')
# Out:
# Text(0, 0.5, 'Price in $')
