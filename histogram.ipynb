# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x = np.random.randint(10,60,(50))

print(x)
# Out:
# [30 31 26 28 32 22 38 26 22 21 27 30 57 34 14 44 18 58 26 18 18 23 21 55
#  36 44 52 38 55 40 56 31 12 21 38 20 44 10 34 13 57 18 56 49 47 37 47 27
#  51 21]

# %%
no=[34,14,38,13,14,23,37,31,32,30,28,40,32,32,16,13,53,20,42,28,22,50,30,32,12,38,39,20,50,21,24,55,47,52,40,21,45,15,31,16,17,33,26,34,17,32,39,22
 ,32,19]

l = [10,20,30,40,50,60] #club or condense data into single unit bins = l
#plt.hist(no, color ="b", bins = l, edgecolor="r",cumulative = -1)
#bottom used for changing origin
#plt.hist(no, color ="b", bins = l, edgecolor="r",cumulative = -1,bottom=10)

#change type of histogram
#plt.hist(no, color ="b", bins = l, edgecolor="r",histtype="step")
#change the orientation
#plt.hist(no, color ="b", bins = l, edgecolor="r",orientation="horizontal")
#change the width of bars
#plt.hist(no, color ="b", bins = l, edgecolor="r",rwidth=0.8)
#in terms of log values frequency
#plt.hist(no, color ="b", bins = l, edgecolor="r",log = True)
#label used with plt.legend()
plt.hist(no, color ="b", bins = l, edgecolor="r",label="python")

plt.title("histogram")
plt.xlabel("python")
plt.ylabel("No.")
plt.legend()
plt.show()
